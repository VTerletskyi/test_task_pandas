# %%
from IPython.display import Image

# %%
Image("app/plots/dev_corners.png")

# %%
Image("app/plots/check_corners.png")

# %%
Image("app/plots/dev_mean.png")

# %%
Image("app/plots/dev_floor.png")

# %%
Image("app/plots/dev_ceiling.png")
